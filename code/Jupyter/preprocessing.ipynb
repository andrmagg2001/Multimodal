# %% [markdown]
# # Preprocessing
#
# This notebook prepares the GRID audio-visual corpus for the multimodal enhancer.
#
# **Pipeline (per speaker `s{i}_processed`, excluding `s21`):**
# - Normalize folders: move `.mpg` into `videos/`, create `audio/`.
# - Extract clean audio (16 kHz mono, PCM) from each video into `audio/`.
# - Synthesize noisy audio in `audio_noisy/` by adding Gaussian noise at a random SNR.
# - Create aligned **train/val/test** splits (80/10/10) by stem for `videos/`, `audio/`, and `audio_noisy/`.
# - Export Mel-spectrogram features (`n_mels=80`) to `.npy` in `audio_mel/` and `audio_noisy_mel/`.
#
# **Resulting structure (per speaker):**

# %%
# import stantment
import os
import shutil
import random
import librosa
import soundfile as sf
import numpy as np
from pathlib import Path
from moviepy import VideoFileClip
from tqdm import tqdm

# costant stantment
ROOT = Path("../../data/dataset")

# %% [markdown]
# ## Normalize per-speaker folders
#
# This cell prepares each `s{i}_processed` directory (excluding `s21`) by:
# - ensuring `videos/` and `audio/` subfolders exist, and
# - moving any loose `*.mpg` files from the speaker root into `videos/`.
#
# **Notes**
# - Idempotent: re-running won’t break the layout (already moved files are skipped).
# - Make sure `ROOT` points to `.../data/dataset`.
# - This step only reorganizes files; audio extraction happens in the next cell.

# %%
for i in range(1,35):
    if i == 21: continue
    
    subject_folder = ROOT / f"s{i}_processed"
    
    if not subject_folder.exists():
        print(f"Directory {subject_folder} not found.")
        continue

    videos_dir = subject_folder / "videos"
    audio_dir  = subject_folder / "audio"
    
    videos_dir.mkdir(exist_ok=True) 
    audio_dir.mkdir(exist_ok=True)

    for file in subject_folder.glob("*.mpg"):
        dest = videos_dir / file.name
        print(f"Change dir for {file} -> {dest}")
        shutil.move(str(file), str(dest))

print("Completed!")
# Out:
# Change dir for ../../data/dataset/s1_processed/prwq3s.mpg -> ../../data/dataset/s1_processed/videos/prwq3s.mpg
# Change dir for ../../data/dataset/s1_processed/pbib8p.mpg -> ../../data/dataset/s1_processed/videos/pbib8p.mpg
# Change dir for ../../data/dataset/s1_processed/lrae3s.mpg -> ../../data/dataset/s1_processed/videos/lrae3s.mpg
# Change dir for ../../data/dataset/s1_processed/pgid6p.mpg -> ../../data/dataset/s1_processed/videos/pgid6p.mpg
# Change dir for ../../data/dataset/s1_processed/pbao8n.mpg -> ../../data/dataset/s1_processed/videos/pbao8n.mpg
# Change dir for ../../data/dataset/s1_processed/prbx3s.mpg -> ../../data/dataset/s1_processed/videos/prbx3s.mpg
# Change dir for ../../data/dataset/s1_processed/lbbk6p.mpg -> ../../data/dataset/s1_processed/videos/lbbk6p.mpg
# Change dir for ../../data/dataset/s1_processed/bgwu6n.mpg -> ../../data/dataset/s1_processed/videos/bgwu6n.mpg
# Change dir for ../../data/dataset/s1_processed/sbig6p.mpg -> ../../data/dataset/s1_processed/videos/sbig6p.mpg
# Change dir for ../../data/dataset/s1_processed/pgby5s.mpg -> ../../data/dataset/s1_processed/videos/pgby5s.mpg
# Change dir for ../../data/dataset/s1_processed/bras8p.mpg -> ../../data/dataset/s1_processed/videos/bras8p.mpg
# Change dir for ../../data/dataset/s1_processed/sgiczp.mpg -> ../../data/dataset/s1_processed/videos/sgiczp.mpg
# Change dir for ../../data/dataset/s1_processed/lrwl7a.mpg -> ../../data/dataset/s1_processed/videos/lrwl7a.mpg
# Change dir for ../../data/dataset/s1_processed/bbbz8n.mpg -> ../../data/dataset/s1_processed/videos/bbbz8n.mpg
# Change dir for ../../data/dataset/s1_processed/bram3s.mpg -> ../../data/dataset/s1_processed/videos/bram3s.mpg
# Change dir for ../../data/dataset/s1_processed/pwwk7a.mpg -> ../../data/dataset/s1_processed/videos/pwwk7a.mpg
# Change dir for ../../data/dataset/s1_processed/bbws8n.mpg -> ../../data/dataset/s1_processed/videos/bbws8n.mpg
# Change dir for ../../data/dataset/s1_processed/brbtzn.mpg -> ../../data/dataset/s1_processed/videos/brbtzn.mpg
# Change dir for ../../data/dataset/s1_processed/bwwbzp.mpg -> ../../data/dataset/s1_processed/videos/bwwbzp.mpg
# Change dir for ../../data/dataset/s1_processed/lrbr5s.mpg -> ../../data/dataset/s1_processed/videos/lrbr5s.mpg
# Change dir for ../../data/dataset/s1_processed/bgwu9a.mpg -> ../../data/dataset/s1_processed/videos/bgwu9a.mpg
# Change dir for ../../data/dataset/s1_processed/lbix6p.mpg -> ../../data/dataset/s1_processed/videos/lbix6p.mpg
# Change dir for ../../data/dataset/s1_processed/lrwz3s.mpg -> ../../data/dataset/s1_processed/videos/lrwz3s.mpg
# Change dir for ../../data/dataset/s1_processed/pwax5s.mpg -> ../../data/dataset/s1_processed/videos/pwax5s.mpg
# Change dir for ../../data/dataset/s1_processed/bwba7a.mpg -> ../../data/dataset/s1_processed/videos/bwba7a.mpg
# Change dir for ../../data/dataset/s1_processed/sria8p.mpg -> ../../data/dataset/s1_processed/videos/sria8p.mpg
# Change dir for ../../data/dataset/s1_processed/bris3s.mpg -> ../../data/dataset/s1_processed/videos/bris3s.mpg
# Change dir for ../../data/dataset/s1_processed/sgwj6p.mpg -> ../../data/dataset/s1_processed/videos/sgwj6p.mpg
# Change dir for ../../data/dataset/s1_processed/bgin2p.mpg -> ../../data/dataset/s1_processed/videos/bgin2p.mpg
# Change dir for ../../data/dataset/s1_processed/sgwj4n.mpg -> ../../data/dataset/s1_processed/videos/sgwj4n.mpg
# Change dir for ../../data/dataset/s1_processed/sgbj2p.mpg -> ../../data/dataset/s1_processed/videos/sgbj2p.mpg
# Change dir for ../../data/dataset/s1_processed/sbit4p.mpg -> ../../data/dataset/s1_processed/videos/sbit4p.mpg
# Change dir for ../../data/dataset/s1_processed/briz7s.mpg -> ../../data/dataset/s1_processed/videos/briz7s.mpg
# Change dir for ../../data/dataset/s1_processed/lwal5a.mpg -> ../../data/dataset/s1_processed/videos/lwal5a.mpg
# Change dir for ../../data/dataset/s1_processed/brbg4p.mpg -> ../../data/dataset/s1_processed/videos/brbg4p.mpg
# Change dir for ../../data/dataset/s1_processed/bwat2n.mpg -> ../../data/dataset/s1_processed/videos/bwat2n.mpg
# Change dir for ../../data/dataset/s1_processed/pwaq1s.mpg -> ../../data/dataset/s1_processed/videos/pwaq1s.mpg
# Change dir for ../../data/dataset/s1_processed/lgif2p.mpg -> ../../data/dataset/s1_processed/videos/lgif2p.mpg
# Change dir for ../../data/dataset/s1_processed/sbwo2p.mpg -> ../../data/dataset/s1_processed/videos/sbwo2p.mpg
# Change dir for ../../data/dataset/s1_processed/lbix4n.mpg -> ../../data/dataset/s1_processed/videos/lbix4n.mpg
# Change dir for ../../data/dataset/s1_processed/prav9s.mpg -> ../../data/dataset/s1_processed/videos/prav9s.mpg
# Change dir for ../../data/dataset/s1_processed/pwbk3a.mpg -> ../../data/dataset/s1_processed/videos/pwbk3a.mpg
# Change dir for ../../data/dataset/s1_processed/lwir5a.mpg -> ../../data/dataset/s1_processed/videos/lwir5a.mpg
# Change dir for ../../data/dataset/s1_processed/bbaf4p.mpg -> ../../data/dataset/s1_processed/videos/bbaf4p.mpg
# Change dir for ../../data/dataset/s1_processed/lrbl3a.mpg -> ../../data/dataset/s1_processed/videos/lrbl3a.mpg
# Change dir for ../../data/dataset/s1_processed/pgak5a.mpg -> ../../data/dataset/s1_processed/videos/pgak5a.mpg
# Change dir for ../../data/dataset/s1_processed/lbiq2p.mpg -> ../../data/dataset/s1_processed/videos/lbiq2p.mpg
# Change dir for ../../data/dataset/s1_processed/bgbu2n.mpg -> ../../data/dataset/s1_processed/videos/bgbu2n.mpg
# Change dir for ../../data/dataset/s1_processed/swai3a.mpg -> ../../data/dataset/s1_processed/videos/swai3a.mpg
# Change dir for ../../data/dataset/s1_processed/sbig4n.mpg -> ../../data/dataset/s1_processed/videos/sbig4n.mpg
# Change dir for ../../data/dataset/s1_processed/praj3a.mpg -> ../../data/dataset/s1_processed/videos/praj3a.mpg
# Change dir for ../../data/dataset/s1_processed/pgid4n.mpg -> ../../data/dataset/s1_processed/videos/pgid4n.mpg
# Change dir for ../../data/dataset/s1_processed/prwx7s.mpg -> ../../data/dataset/s1_processed/videos/prwx7s.mpg
# Change dir for ../../data/dataset/s1_processed/srwv1s.mpg -> ../../data/dataset/s1_processed/videos/srwv1s.mpg
# Change dir for ../../data/dataset/s1_processed/lbbk4n.mpg -> ../../data/dataset/s1_processed/videos/lbbk4n.mpg
# Change dir for ../../data/dataset/s1_processed/lgbm5a.mpg -> ../../data/dataset/s1_processed/videos/lgbm5a.mpg
# Change dir for ../../data/dataset/s1_processed/pwix3a.mpg -> ../../data/dataset/s1_processed/videos/pwix3a.mpg
# Change dir for ../../data/dataset/s1_processed/lwaz1s.mpg -> ../../data/dataset/s1_processed/videos/lwaz1s.mpg
# Change dir for ../../data/dataset/s1_processed/swau9s.mpg -> ../../data/dataset/s1_processed/videos/swau9s.mpg
# Change dir for ../../data/dataset/s1_processed/pgwl2p.mpg -> ../../data/dataset/s1_processed/videos/pgwl2p.mpg
# Change dir for ../../data/dataset/s1_processed/pbwj2n.mpg -> ../../data/dataset/s1_processed/videos/pbwj2n.mpg
# Change dir for ../../data/dataset/s1_processed/pgwl3a.mpg -> ../../data/dataset/s1_processed/videos/pgwl3a.mpg
# Change dir for ../../data/dataset/s1_processed/sgap1s.mpg -> ../../data/dataset/s1_processed/videos/sgap1s.mpg
# Change dir for ../../data/dataset/s1_processed/pgij9s.mpg -> ../../data/dataset/s1_processed/videos/pgij9s.mpg
# Change dir for ../../data/dataset/s1_processed/praj2p.mpg -> ../../data/dataset/s1_processed/videos/praj2p.mpg
# Change dir for ../../data/dataset/s1_processed/pgbr1s.mpg -> ../../data/dataset/s1_processed/videos/pgbr1s.mpg
# Change dir for ../../data/dataset/s1_processed/lwwf7s.mpg -> ../../data/dataset/s1_processed/videos/lwwf7s.mpg
# Change dir for ../../data/dataset/s1_processed/lgbm4p.mpg -> ../../data/dataset/s1_processed/videos/lgbm4p.mpg
# Change dir for ../../data/dataset/s1_processed/pwix2p.mpg -> ../../data/dataset/s1_processed/videos/pwix2p.mpg
# Change dir for ../../data/dataset/s1_processed/lrwl4n.mpg -> ../../data/dataset/s1_processed/videos/lrwl4n.mpg
# Change dir for ../../data/dataset/s1_processed/bbaf5a.mpg -> ../../data/dataset/s1_processed/videos/bbaf5a.mpg
# Change dir for ../../data/dataset/s1_processed/bwwn7s.mpg -> ../../data/dataset/s1_processed/videos/bwwn7s.mpg
# Change dir for ../../data/dataset/s1_processed/lrbl2p.mpg -> ../../data/dataset/s1_processed/videos/lrbl2p.mpg
# Change dir for ../../data/dataset/s1_processed/swai2p.mpg -> ../../data/dataset/s1_processed/videos/swai2p.mpg
# Change dir for ../../data/dataset/s1_processed/lbiq3a.mpg -> ../../data/dataset/s1_processed/videos/lbiq3a.mpg
# Change dir for ../../data/dataset/s1_processed/pgak4p.mpg -> ../../data/dataset/s1_processed/videos/pgak4p.mpg
# Change dir for ../../data/dataset/s1_processed/sbba9s.mpg -> ../../data/dataset/s1_processed/videos/sbba9s.mpg
# Change dir for ../../data/dataset/s1_processed/sbwo3a.mpg -> ../../data/dataset/s1_processed/videos/sbwo3a.mpg
# Change dir for ../../data/dataset/s1_processed/bbie9s.mpg -> ../../data/dataset/s1_processed/videos/bbie9s.mpg
# Change dir for ../../data/dataset/s1_processed/lwir4p.mpg -> ../../data/dataset/s1_processed/videos/lwir4p.mpg
# Change dir for ../../data/dataset/s1_processed/sgio7s.mpg -> ../../data/dataset/s1_processed/videos/sgio7s.mpg
# Change dir for ../../data/dataset/s1_processed/pwwk4n.mpg -> ../../data/dataset/s1_processed/videos/pwwk4n.mpg
# Change dir for ../../data/dataset/s1_processed/pwbk2p.mpg -> ../../data/dataset/s1_processed/videos/pwbk2p.mpg
# Change dir for ../../data/dataset/s1_processed/pwbd7s.mpg -> ../../data/dataset/s1_processed/videos/pwbd7s.mpg
# Change dir for ../../data/dataset/s1_processed/lgif3a.mpg -> ../../data/dataset/s1_processed/videos/lgif3a.mpg
# Change dir for ../../data/dataset/s1_processed/brbg5a.mpg -> ../../data/dataset/s1_processed/videos/brbg5a.mpg
# Change dir for ../../data/dataset/s1_processed/sgbv9s.mpg -> ../../data/dataset/s1_processed/videos/sgbv9s.mpg
# Change dir for ../../data/dataset/s1_processed/bwba4n.mpg -> ../../data/dataset/s1_processed/videos/bwba4n.mpg
# Change dir for ../../data/dataset/s1_processed/srwi2n.mpg -> ../../data/dataset/s1_processed/videos/srwi2n.mpg
# Change dir for ../../data/dataset/s1_processed/lwal4p.mpg -> ../../data/dataset/s1_processed/videos/lwal4p.mpg
# Change dir for ../../data/dataset/s1_processed/bgwh9s.mpg -> ../../data/dataset/s1_processed/videos/bgwh9s.mpg
# Change dir for ../../data/dataset/s1_processed/sbit5a.mpg -> ../../data/dataset/s1_processed/videos/sbit5a.mpg
# Change dir for ../../data/dataset/s1_processed/sgbj3a.mpg -> ../../data/dataset/s1_processed/videos/sgbj3a.mpg
# Change dir for ../../data/dataset/s1_processed/bgin3a.mpg -> ../../data/dataset/s1_processed/videos/bgin3a.mpg
# Change dir for ../../data/dataset/s1_processed/sria6n.mpg -> ../../data/dataset/s1_processed/videos/sria6n.mpg
# Change dir for ../../data/dataset/s1_processed/lriezp.mpg -> ../../data/dataset/s1_processed/videos/lriezp.mpg
# Change dir for ../../data/dataset/s1_processed/swbo8n.mpg -> ../../data/dataset/s1_processed/videos/swbo8n.mpg
# Change dir for ../../data/dataset/s1_processed/sgwj7a.mpg -> ../../data/dataset/s1_processed/videos/sgwj7a.mpg
# Change dir for ../../data/dataset/s1_processed/lbaq5s.mpg -> ../../data/dataset/s1_processed/videos/lbaq5s.mpg
# Change dir for ../../data/dataset/s1_processed/sria9a.mpg -> ../../data/dataset/s1_processed/videos/sria9a.mpg
# Change dir for ../../data/dataset/s1_processed/sran8n.mpg -> ../../data/dataset/s1_processed/videos/sran8n.mpg
# Change dir for ../../data/dataset/s1_processed/bwba6p.mpg -> ../../data/dataset/s1_processed/videos/bwba6p.mpg
# Change dir for ../../data/dataset/s1_processed/srbizp.mpg -> ../../data/dataset/s1_processed/videos/srbizp.mpg
# Change dir for ../../data/dataset/s1_processed/sgac3s.mpg -> ../../data/dataset/s1_processed/videos/sgac3s.mpg
# Change dir for ../../data/dataset/s1_processed/brimzp.mpg -> ../../data/dataset/s1_processed/videos/brimzp.mpg
# Change dir for ../../data/dataset/s1_processed/pwwk6p.mpg -> ../../data/dataset/s1_processed/videos/pwwk6p.mpg
# Change dir for ../../data/dataset/s1_processed/sbahzp.mpg -> ../../data/dataset/s1_processed/videos/sbahzp.mpg
# Change dir for ../../data/dataset/s1_processed/lbix7a.mpg -> ../../data/dataset/s1_processed/videos/lbix7a.mpg
# Change dir for ../../data/dataset/s1_processed/bras6n.mpg -> ../../data/dataset/s1_processed/videos/bras6n.mpg
# Change dir for ../../data/dataset/s1_processed/bgwu8p.mpg -> ../../data/dataset/s1_processed/videos/bgwu8p.mpg
# Change dir for ../../data/dataset/s1_processed/bgan5s.mpg -> ../../data/dataset/s1_processed/videos/bgan5s.mpg
# Change dir for ../../data/dataset/s1_processed/sbig7a.mpg -> ../../data/dataset/s1_processed/videos/sbig7a.mpg
# Change dir for ../../data/dataset/s1_processed/pbbjzp.mpg -> ../../data/dataset/s1_processed/videos/pbbjzp.mpg
# Change dir for ../../data/dataset/s1_processed/bras9a.mpg -> ../../data/dataset/s1_processed/videos/bras9a.mpg
# Change dir for ../../data/dataset/s1_processed/srao1a.mpg -> ../../data/dataset/s1_processed/videos/srao1a.mpg
# Change dir for ../../data/dataset/s1_processed/bwbn3s.mpg -> ../../data/dataset/s1_processed/videos/bwbn3s.mpg
# Change dir for ../../data/dataset/s1_processed/lrwl6p.mpg -> ../../data/dataset/s1_processed/videos/lrwl6p.mpg
# Change dir for ../../data/dataset/s1_processed/pgwr5s.mpg -> ../../data/dataset/s1_processed/videos/pgwr5s.mpg
# Change dir for ../../data/dataset/s1_processed/lwbf3s.mpg -> ../../data/dataset/s1_processed/videos/lwbf3s.mpg
# Change dir for ../../data/dataset/s1_processed/pbib6n.mpg -> ../../data/dataset/s1_processed/videos/pbib6n.mpg
# Change dir for ../../data/dataset/s1_processed/swwp3s.mpg -> ../../data/dataset/s1_processed/videos/swwp3s.mpg
# Change dir for ../../data/dataset/s1_processed/lbbk7a.mpg -> ../../data/dataset/s1_processed/videos/lbbk7a.mpg
# Change dir for ../../data/dataset/s1_processed/pgid7a.mpg -> ../../data/dataset/s1_processed/videos/pgid7a.mpg
# Change dir for ../../data/dataset/s1_processed/lgaf5s.mpg -> ../../data/dataset/s1_processed/videos/lgaf5s.mpg
# Change dir for ../../data/dataset/s1_processed/pbib9a.mpg -> ../../data/dataset/s1_processed/videos/pbib9a.mpg
# Change dir for ../../data/dataset/s1_processed/sgivzn.mpg -> ../../data/dataset/s1_processed/videos/sgivzn.mpg
# Change dir for ../../data/dataset/s1_processed/braf8n.mpg -> ../../data/dataset/s1_processed/videos/braf8n.mpg
# Change dir for ../../data/dataset/s1_processed/bwim6p.mpg -> ../../data/dataset/s1_processed/videos/bwim6p.mpg
# Change dir for ../../data/dataset/s1_processed/swbi6p.mpg -> ../../data/dataset/s1_processed/videos/swbi6p.mpg
# Change dir for ../../data/dataset/s1_processed/pgbe3s.mpg -> ../../data/dataset/s1_processed/videos/pgbe3s.mpg
# Change dir for ../../data/dataset/s1_processed/brbazp.mpg -> ../../data/dataset/s1_processed/videos/brbazp.mpg
# Change dir for ../../data/dataset/s1_processed/bgwb7a.mpg -> ../../data/dataset/s1_processed/videos/bgwb7a.mpg
# Change dir for ../../data/dataset/s1_processed/lray5s.mpg -> ../../data/dataset/s1_processed/videos/lray5s.mpg
# Change dir for ../../data/dataset/s1_processed/bbwt1a.mpg -> ../../data/dataset/s1_processed/videos/bbwt1a.mpg
# Change dir for ../../data/dataset/s1_processed/bwbg8n.mpg -> ../../data/dataset/s1_processed/videos/bwbg8n.mpg
# Change dir for ../../data/dataset/s1_processed/srah6p.mpg -> ../../data/dataset/s1_processed/videos/srah6p.mpg
# Change dir for ../../data/dataset/s1_processed/sgbp5s.mpg -> ../../data/dataset/s1_processed/videos/sgbp5s.mpg
# Change dir for ../../data/dataset/s1_processed/bbaszn.mpg -> ../../data/dataset/s1_processed/videos/bbaszn.mpg
# Change dir for ../../data/dataset/s1_processed/bgit5s.mpg -> ../../data/dataset/s1_processed/videos/bgit5s.mpg
# Change dir for ../../data/dataset/s1_processed/sbwh9a.mpg -> ../../data/dataset/s1_processed/videos/sbwh9a.mpg
# Change dir for ../../data/dataset/s1_processed/lbby3s.mpg -> ../../data/dataset/s1_processed/videos/lbby3s.mpg
# Change dir for ../../data/dataset/s1_processed/prbj6p.mpg -> ../../data/dataset/s1_processed/videos/prbj6p.mpg
# Change dir for ../../data/dataset/s1_processed/sbwh6n.mpg -> ../../data/dataset/s1_processed/videos/sbwh6n.mpg
# Change dir for ../../data/dataset/s1_processed/lwie6p.mpg -> ../../data/dataset/s1_processed/videos/lwie6p.mpg
# Change dir for ../../data/dataset/s1_processed/lbwlzp.mpg -> ../../data/dataset/s1_processed/videos/lbwlzp.mpg
# Change dir for ../../data/dataset/s1_processed/sriu1a.mpg -> ../../data/dataset/s1_processed/videos/sriu1a.mpg
# Change dir for ../../data/dataset/s1_processed/srit8n.mpg -> ../../data/dataset/s1_processed/videos/srit8n.mpg
# Change dir for ../../data/dataset/s1_processed/lgwg3s.mpg -> ../../data/dataset/s1_processed/videos/lgwg3s.mpg
# Change dir for ../../data/dataset/s1_processed/sgwx3s.mpg -> ../../data/dataset/s1_processed/videos/sgwx3s.mpg
# Change dir for ../../data/dataset/s1_processed/pbiv1a.mpg -> ../../data/dataset/s1_processed/videos/pbiv1a.mpg
# Change dir for ../../data/dataset/s1_processed/pwad3s.mpg -> ../../data/dataset/s1_processed/videos/pwad3s.mpg
# Change dir for ../../data/dataset/s1_processed/sbiazn.mpg -> ../../data/dataset/s1_processed/videos/sbiazn.mpg
# Change dir for ../../data/dataset/s1_processed/bwbt8p.mpg -> ../../data/dataset/s1_processed/videos/bwbt8p.mpg
# Change dir for ../../data/dataset/s1_processed/pbai7a.mpg -> ../../data/dataset/s1_processed/videos/pbai7a.mpg
# Change dir for ../../data/dataset/s1_processed/sbwu5s.mpg -> ../../data/dataset/s1_processed/videos/sbwu5s.mpg
# Change dir for ../../data/dataset/s1_processed/bgwo3s.mpg -> ../../data/dataset/s1_processed/videos/bgwo3s.mpg
# Change dir for ../../data/dataset/s1_processed/brag1a.mpg -> ../../data/dataset/s1_processed/videos/brag1a.mpg
# Change dir for ../../data/dataset/s1_processed/prwkzp.mpg -> ../../data/dataset/s1_processed/videos/prwkzp.mpg
# Change dir for ../../data/dataset/s1_processed/bwaa2p.mpg -> ../../data/dataset/s1_processed/videos/bwaa2p.mpg
# Change dir for ../../data/dataset/s1_processed/lgiz4p.mpg -> ../../data/dataset/s1_processed/videos/lgiz4p.mpg
# Change dir for ../../data/dataset/s1_processed/sban5a.mpg -> ../../data/dataset/s1_processed/videos/sban5a.mpg
# Change dir for ../../data/dataset/s1_processed/bgig7s.mpg -> ../../data/dataset/s1_processed/videos/bgig7s.mpg
# Change dir for ../../data/dataset/s1_processed/sbbu1s.mpg -> ../../data/dataset/s1_processed/videos/sbbu1s.mpg
# Change dir for ../../data/dataset/s1_processed/sgbc7s.mpg -> ../../data/dataset/s1_processed/videos/sgbc7s.mpg
# Change dir for ../../data/dataset/s1_processed/lriy3a.mpg -> ../../data/dataset/s1_processed/videos/lriy3a.mpg
# Change dir for ../../data/dataset/s1_processed/sbim9s.mpg -> ../../data/dataset/s1_processed/videos/sbim9s.mpg
# Change dir for ../../data/dataset/s1_processed/bbwg3a.mpg -> ../../data/dataset/s1_processed/videos/bbwg3a.mpg
# Change dir for ../../data/dataset/s1_processed/pric2n.mpg -> ../../data/dataset/s1_processed/videos/pric2n.mpg
# Change dir for ../../data/dataset/s1_processed/lbwy7s.mpg -> ../../data/dataset/s1_processed/videos/lbwy7s.mpg
# Change dir for ../../data/dataset/s1_processed/prbj4n.mpg -> ../../data/dataset/s1_processed/videos/prbj4n.mpg
# Change dir for ../../data/dataset/s1_processed/bbil2n.mpg -> ../../data/dataset/s1_processed/videos/bbil2n.mpg
# Change dir for ../../data/dataset/s1_processed/sbbh2n.mpg -> ../../data/dataset/s1_processed/videos/sbbh2n.mpg
# Change dir for ../../data/dataset/s1_processed/pgiq4p.mpg -> ../../data/dataset/s1_processed/videos/pgiq4p.mpg
# Change dir for ../../data/dataset/s1_processed/lbak3a.mpg -> ../../data/dataset/s1_processed/videos/lbak3a.mpg
# Change dir for ../../data/dataset/s1_processed/brwa2n.mpg -> ../../data/dataset/s1_processed/videos/brwa2n.mpg
# Change dir for ../../data/dataset/s1_processed/lwie4n.mpg -> ../../data/dataset/s1_processed/videos/lwie4n.mpg
# Change dir for ../../data/dataset/s1_processed/pbii1s.mpg -> ../../data/dataset/s1_processed/videos/pbii1s.mpg
# Change dir for ../../data/dataset/s1_processed/lwwm2p.mpg -> ../../data/dataset/s1_processed/videos/lwwm2p.mpg
# Change dir for ../../data/dataset/s1_processed/bgbb3a.mpg -> ../../data/dataset/s1_processed/videos/bgbb3a.mpg
# Change dir for ../../data/dataset/s1_processed/srah4n.mpg -> ../../data/dataset/s1_processed/videos/srah4n.mpg
# Change dir for ../../data/dataset/s1_processed/swab7s.mpg -> ../../data/dataset/s1_processed/videos/swab7s.mpg
# Change dir for ../../data/dataset/s1_processed/pgwe7s.mpg -> ../../data/dataset/s1_processed/videos/pgwe7s.mpg
# Change dir for ../../data/dataset/s1_processed/bwim4n.mpg -> ../../data/dataset/s1_processed/videos/bwim4n.mpg
# Change dir for ../../data/dataset/s1_processed/lbid2n.mpg -> ../../data/dataset/s1_processed/videos/lbid2n.mpg
# Change dir for ../../data/dataset/s1_processed/swbi4n.mpg -> ../../data/dataset/s1_processed/videos/swbi4n.mpg
# Change dir for ../../data/dataset/s1_processed/lgwt1s.mpg -> ../../data/dataset/s1_processed/videos/lgwt1s.mpg
# Change dir for ../../data/dataset/s1_processed/prip2p.mpg -> ../../data/dataset/s1_processed/videos/prip2p.mpg
# Change dir for ../../data/dataset/s1_processed/srbo5a.mpg -> ../../data/dataset/s1_processed/videos/srbo5a.mpg
# Change dir for ../../data/dataset/s1_processed/pbwc9s.mpg -> ../../data/dataset/s1_processed/videos/pbwc9s.mpg
# Change dir for ../../data/dataset/s1_processed/prip3a.mpg -> ../../data/dataset/s1_processed/videos/prip3a.mpg
# Change dir for ../../data/dataset/s1_processed/pgay1s.mpg -> ../../data/dataset/s1_processed/videos/pgay1s.mpg
# Change dir for ../../data/dataset/s1_processed/prac7s.mpg -> ../../data/dataset/s1_processed/videos/prac7s.mpg
# Change dir for ../../data/dataset/s1_processed/brbm7s.mpg -> ../../data/dataset/s1_processed/videos/brbm7s.mpg
# Change dir for ../../data/dataset/s1_processed/srbo4p.mpg -> ../../data/dataset/s1_processed/videos/srbo4p.mpg
# Change dir for ../../data/dataset/s1_processed/lrar1s.mpg -> ../../data/dataset/s1_processed/videos/lrar1s.mpg
# Change dir for ../../data/dataset/s1_processed/lwwm3a.mpg -> ../../data/dataset/s1_processed/videos/lwwm3a.mpg
# Change dir for ../../data/dataset/s1_processed/bgbb2p.mpg -> ../../data/dataset/s1_processed/videos/bgbb2p.mpg
# Change dir for ../../data/dataset/s1_processed/bbir7s.mpg -> ../../data/dataset/s1_processed/videos/bbir7s.mpg
# Change dir for ../../data/dataset/s1_processed/bgwb4n.mpg -> ../../data/dataset/s1_processed/videos/bgwb4n.mpg
# Change dir for ../../data/dataset/s1_processed/lwbs1s.mpg -> ../../data/dataset/s1_processed/videos/lwbs1s.mpg
# Change dir for ../../data/dataset/s1_processed/lrbe7s.mpg -> ../../data/dataset/s1_processed/videos/lrbe7s.mpg
# Change dir for ../../data/dataset/s1_processed/lbak2p.mpg -> ../../data/dataset/s1_processed/videos/lbak2p.mpg
# Change dir for ../../data/dataset/s1_processed/pgiq5a.mpg -> ../../data/dataset/s1_processed/videos/pgiq5a.mpg
# Change dir for ../../data/dataset/s1_processed/lwik9s.mpg -> ../../data/dataset/s1_processed/videos/lwik9s.mpg
# Change dir for ../../data/dataset/s1_processed/lbad7s.mpg -> ../../data/dataset/s1_processed/videos/lbad7s.mpg
# Change dir for ../../data/dataset/s1_processed/srwb9s.mpg -> ../../data/dataset/s1_processed/videos/srwb9s.mpg
# Change dir for ../../data/dataset/s1_processed/pbwp7s.mpg -> ../../data/dataset/s1_processed/videos/pbwp7s.mpg
# Change dir for ../../data/dataset/s1_processed/swib2n.mpg -> ../../data/dataset/s1_processed/videos/swib2n.mpg
# Change dir for ../../data/dataset/s1_processed/pbai4n.mpg -> ../../data/dataset/s1_processed/videos/pbai4n.mpg
# Change dir for ../../data/dataset/s1_processed/srih1s.mpg -> ../../data/dataset/s1_processed/videos/srih1s.mpg
# Change dir for ../../data/dataset/s1_processed/bbwg2p.mpg -> ../../data/dataset/s1_processed/videos/bbwg2p.mpg
# Change dir for ../../data/dataset/s1_processed/lriy2p.mpg -> ../../data/dataset/s1_processed/videos/lriy2p.mpg
# Change dir for ../../data/dataset/s1_processed/bwaa3a.mpg -> ../../data/dataset/s1_processed/videos/bwaa3a.mpg
# Change dir for ../../data/dataset/s1_processed/lgiz5a.mpg -> ../../data/dataset/s1_processed/videos/lgiz5a.mpg
# Change dir for ../../data/dataset/s1_processed/sban4p.mpg -> ../../data/dataset/s1_processed/videos/sban4p.mpg
# Change dir for ../../data/dataset/s1_processed/bbal7s.mpg -> ../../data/dataset/s1_processed/videos/bbal7s.mpg
# Change dir for ../../data/dataset/s1_processed/bwbt6n.mpg -> ../../data/dataset/s1_processed/videos/bwbt6n.mpg
# Change dir for ../../data/dataset/s1_processed/bwbt9a.mpg -> ../../data/dataset/s1_processed/videos/bwbt9a.mpg
# Change dir for ../../data/dataset/s1_processed/pwbq5s.mpg -> ../../data/dataset/s1_processed/videos/pwbq5s.mpg
# Change dir for ../../data/dataset/s1_processed/lgis1a.mpg -> ../../data/dataset/s1_processed/videos/lgis1a.mpg
# Change dir for ../../data/dataset/s1_processed/pbai6p.mpg -> ../../data/dataset/s1_processed/videos/pbai6p.mpg
# Change dir for ../../data/dataset/s1_processed/swwjzp.mpg -> ../../data/dataset/s1_processed/videos/swwjzp.mpg
# Change dir for ../../data/dataset/s1_processed/pbbp3s.mpg -> ../../data/dataset/s1_processed/videos/pbbp3s.mpg
# Change dir for ../../data/dataset/s1_processed/lgal8n.mpg -> ../../data/dataset/s1_processed/videos/lgal8n.mpg
# Change dir for ../../data/dataset/s1_processed/prap5s.mpg -> ../../data/dataset/s1_processed/videos/prap5s.mpg
# Change dir for ../../data/dataset/s1_processed/lwie7a.mpg -> ../../data/dataset/s1_processed/videos/lwie7a.mpg
# Change dir for ../../data/dataset/s1_processed/bwwuzn.mpg -> ../../data/dataset/s1_processed/videos/bwwuzn.mpg
# Change dir for ../../data/dataset/s1_processed/prbj7a.mpg -> ../../data/dataset/s1_processed/videos/prbj7a.mpg
# Change dir for ../../data/dataset/s1_processed/lgam1a.mpg -> ../../data/dataset/s1_processed/videos/lgam1a.mpg
# Change dir for ../../data/dataset/s1_processed/lwws5s.mpg -> ../../data/dataset/s1_processed/videos/lwws5s.mpg
# Change dir for ../../data/dataset/s1_processed/bgauzp.mpg -> ../../data/dataset/s1_processed/videos/bgauzp.mpg
# Change dir for ../../data/dataset/s1_processed/srah7a.mpg -> ../../data/dataset/s1_processed/videos/srah7a.mpg
# Change dir for ../../data/dataset/s1_processed/lwbz5s.mpg -> ../../data/dataset/s1_processed/videos/lwbz5s.mpg
# Change dir for ../../data/dataset/s1_processed/bgwb6p.mpg -> ../../data/dataset/s1_processed/videos/bgwb6p.mpg
# Change dir for ../../data/dataset/s1_processed/sbwh8p.mpg -> ../../data/dataset/s1_processed/videos/sbwh8p.mpg
# Change dir for ../../data/dataset/s1_processed/lgir8n.mpg -> ../../data/dataset/s1_processed/videos/lgir8n.mpg
# Change dir for ../../data/dataset/s1_processed/pwwy3s.mpg -> ../../data/dataset/s1_processed/videos/pwwy3s.mpg
# Change dir for ../../data/dataset/s1_processed/lbwr3s.mpg -> ../../data/dataset/s1_processed/videos/lbwr3s.mpg
# Change dir for ../../data/dataset/s1_processed/pbiu8n.mpg -> ../../data/dataset/s1_processed/videos/pbiu8n.mpg
# Change dir for ../../data/dataset/s1_processed/pwidzp.mpg -> ../../data/dataset/s1_processed/videos/pwidzp.mpg
# Change dir for ../../data/dataset/s1_processed/swbi7a.mpg -> ../../data/dataset/s1_processed/videos/swbi7a.mpg
# Change dir for ../../data/dataset/s1_processed/bwim7a.mpg -> ../../data/dataset/s1_processed/videos/bwim7a.mpg
# Change dir for ../../data/dataset/s1_processed/lbwr4p.mpg -> ../../data/dataset/s1_processed/videos/lbwr4p.mpg
# Change dir for ../../data/dataset/s1_processed/srwo7s.mpg -> ../../data/dataset/s1_processed/videos/srwo7s.mpg
# Change dir for ../../data/dataset/s1_processed/bbbf7s.mpg -> ../../data/dataset/s1_processed/videos/bbbf7s.mpg
# Change dir for ../../data/dataset/s1_processed/swio3a.mpg -> ../../data/dataset/s1_processed/videos/swio3a.mpg
# Change dir for ../../data/dataset/s1_processed/sbaa4n.mpg -> ../../data/dataset/s1_processed/videos/sbaa4n.mpg
# Change dir for ../../data/dataset/s1_processed/swwi9s.mpg -> ../../data/dataset/s1_processed/videos/swwi9s.mpg
# Change dir for ../../data/dataset/s1_processed/pgbe5a.mpg -> ../../data/dataset/s1_processed/videos/pgbe5a.mpg
# Change dir for ../../data/dataset/s1_processed/lgil4n.mpg -> ../../data/dataset/s1_processed/videos/lgil4n.mpg
# Change dir for ../../data/dataset/s1_processed/pwwy4p.mpg -> ../../data/dataset/s1_processed/videos/pwwy4p.mpg
# Change dir for ../../data/dataset/s1_processed/lriq7s.mpg -> ../../data/dataset/s1_processed/videos/lriq7s.mpg
# Change dir for ../../data/dataset/s1_processed/pbbc4n.mpg -> ../../data/dataset/s1_processed/videos/pbbc4n.mpg
# Change dir for ../../data/dataset/s1_processed/bwwu1s.mpg -> ../../data/dataset/s1_processed/videos/bwwu1s.mpg
# Change dir for ../../data/dataset/s1_processed/pbwx2p.mpg -> ../../data/dataset/s1_processed/videos/pbwx2p.mpg
# Change dir for ../../data/dataset/s1_processed/prbd3a.mpg -> ../../data/dataset/s1_processed/videos/prbd3a.mpg
# Change dir for ../../data/dataset/s1_processed/lgas2n.mpg -> ../../data/dataset/s1_processed/videos/lgas2n.mpg
# Change dir for ../../data/dataset/s1_processed/prwj9s.mpg -> ../../data/dataset/s1_processed/videos/prwj9s.mpg
# Change dir for ../../data/dataset/s1_processed/lbby5a.mpg -> ../../data/dataset/s1_processed/videos/lbby5a.mpg
# Change dir for ../../data/dataset/s1_processed/pwij2n.mpg -> ../../data/dataset/s1_processed/videos/pwij2n.mpg
# Change dir for ../../data/dataset/s1_processed/bwwh2n.mpg -> ../../data/dataset/s1_processed/videos/bwwh2n.mpg
# Change dir for ../../data/dataset/s1_processed/brwn3a.mpg -> ../../data/dataset/s1_processed/videos/brwn3a.mpg
# Change dir for ../../data/dataset/s1_processed/lgwg5a.mpg -> ../../data/dataset/s1_processed/videos/lgwg5a.mpg
# Change dir for ../../data/dataset/s1_processed/sgwx5a.mpg -> ../../data/dataset/s1_processed/videos/sgwx5a.mpg
# Change dir for ../../data/dataset/s1_processed/bgah2p.mpg -> ../../data/dataset/s1_processed/videos/bgah2p.mpg
# Change dir for ../../data/dataset/s1_processed/pbbp4p.mpg -> ../../data/dataset/s1_processed/videos/pbbp4p.mpg
# Change dir for ../../data/dataset/s1_processed/sgii2n.mpg -> ../../data/dataset/s1_processed/videos/sgii2n.mpg
# Change dir for ../../data/dataset/s1_processed/bbiz2p.mpg -> ../../data/dataset/s1_processed/videos/bbiz2p.mpg
# Change dir for ../../data/dataset/s1_processed/pwad5a.mpg -> ../../data/dataset/s1_processed/videos/pwad5a.mpg
# Change dir for ../../data/dataset/s1_processed/sgav4n.mpg -> ../../data/dataset/s1_processed/videos/sgav4n.mpg
# Change dir for ../../data/dataset/s1_processed/bgwo5a.mpg -> ../../data/dataset/s1_processed/videos/bgwo5a.mpg
# Change dir for ../../data/dataset/s1_processed/lrwf3a.mpg -> ../../data/dataset/s1_processed/videos/lrwf3a.mpg
# Change dir for ../../data/dataset/s1_processed/swbv2n.mpg -> ../../data/dataset/s1_processed/videos/swbv2n.mpg
# Change dir for ../../data/dataset/s1_processed/swwv6n.mpg -> ../../data/dataset/s1_processed/videos/swwv6n.mpg
# Change dir for ../../data/dataset/s1_processed/sban3s.mpg -> ../../data/dataset/s1_processed/videos/sban3s.mpg
# Change dir for ../../data/dataset/s1_processed/pgaq6n.mpg -> ../../data/dataset/s1_processed/videos/pgaq6n.mpg
# Change dir for ../../data/dataset/s1_processed/bgbo1a.mpg -> ../../data/dataset/s1_processed/videos/bgbo1a.mpg
# Change dir for ../../data/dataset/s1_processed/bwbhzp.mpg -> ../../data/dataset/s1_processed/videos/bwbhzp.mpg
# Change dir for ../../data/dataset/s1_processed/pgaq9a.mpg -> ../../data/dataset/s1_processed/videos/pgaq9a.mpg
# Change dir for ../../data/dataset/s1_processed/sgav6p.mpg -> ../../data/dataset/s1_processed/videos/sgav6p.mpg
# Change dir for ../../data/dataset/s1_processed/swwv9a.mpg -> ../../data/dataset/s1_processed/videos/swwv9a.mpg
# Change dir for ../../data/dataset/s1_processed/srbb7a.mpg -> ../../data/dataset/s1_processed/videos/srbb7a.mpg
# Change dir for ../../data/dataset/s1_processed/brif7a.mpg -> ../../data/dataset/s1_processed/videos/brif7a.mpg
# Change dir for ../../data/dataset/s1_processed/sgbx1a.mpg -> ../../data/dataset/s1_processed/videos/sgbx1a.mpg
# Change dir for ../../data/dataset/s1_processed/lbbq8n.mpg -> ../../data/dataset/s1_processed/videos/lbbq8n.mpg
# Change dir for ../../data/dataset/s1_processed/sgwq1a.mpg -> ../../data/dataset/s1_processed/videos/sgwq1a.mpg
# Change dir for ../../data/dataset/s1_processed/swao5s.mpg -> ../../data/dataset/s1_processed/videos/swao5s.mpg
# Change dir for ../../data/dataset/s1_processed/srihzn.mpg -> ../../data/dataset/s1_processed/videos/srihzn.mpg
# Change dir for ../../data/dataset/s1_processed/lgbg1a.mpg -> ../../data/dataset/s1_processed/videos/lgbg1a.mpg
# Change dir for ../../data/dataset/s1_processed/lrarzn.mpg -> ../../data/dataset/s1_processed/videos/lrarzn.mpg
# Change dir for ../../data/dataset/s1_processed/lwaf1a.mpg -> ../../data/dataset/s1_processed/videos/lwaf1a.mpg
# Change dir for ../../data/dataset/s1_processed/lgbf8n.mpg -> ../../data/dataset/s1_processed/videos/lgbf8n.mpg
# Change dir for ../../data/dataset/s1_processed/lgaz6n.mpg -> ../../data/dataset/s1_processed/videos/lgaz6n.mpg
# Change dir for ../../data/dataset/s1_processed/sgwp8n.mpg -> ../../data/dataset/s1_processed/videos/sgwp8n.mpg
# Change dir for ../../data/dataset/s1_processed/prwd7a.mpg -> ../../data/dataset/s1_processed/videos/prwd7a.mpg
# Change dir for ../../data/dataset/s1_processed/lgaz9a.mpg -> ../../data/dataset/s1_processed/videos/lgaz9a.mpg
# Change dir for ../../data/dataset/s1_processed/pwwr1a.mpg -> ../../data/dataset/s1_processed/videos/pwwr1a.mpg
# Change dir for ../../data/dataset/s1_processed/pgayzn.mpg -> ../../data/dataset/s1_processed/videos/pgayzn.mpg
# Change dir for ../../data/dataset/s1_processed/lgil6p.mpg -> ../../data/dataset/s1_processed/videos/lgil6p.mpg
# Change dir for ../../data/dataset/s1_processed/pbbc6p.mpg -> ../../data/dataset/s1_processed/videos/pbbc6p.mpg
# Change dir for ../../data/dataset/s1_processed/lwbszn.mpg -> ../../data/dataset/s1_processed/videos/lwbszn.mpg
# Change dir for ../../data/dataset/s1_processed/sbaa6p.mpg -> ../../data/dataset/s1_processed/videos/sbaa6p.mpg
# Change dir for ../../data/dataset/s1_processed/lbij8p.mpg -> ../../data/dataset/s1_processed/videos/lbij8p.mpg
# Change dir for ../../data/dataset/s1_processed/bgbn8n.mpg -> ../../data/dataset/s1_processed/videos/bgbn8n.mpg
# Change dir for ../../data/dataset/s1_processed/bwan1a.mpg -> ../../data/dataset/s1_processed/videos/bwan1a.mpg
# Change dir for ../../data/dataset/s1_processed/srbo3s.mpg -> ../../data/dataset/s1_processed/videos/srbo3s.mpg
# Change dir for ../../data/dataset/s1_processed/lbij9a.mpg -> ../../data/dataset/s1_processed/videos/lbij9a.mpg
# Change dir for ../../data/dataset/s1_processed/sbaa7a.mpg -> ../../data/dataset/s1_processed/videos/sbaa7a.mpg
# Change dir for ../../data/dataset/s1_processed/lbbr1a.mpg -> ../../data/dataset/s1_processed/videos/lbbr1a.mpg
# Change dir for ../../data/dataset/s1_processed/bwis8n.mpg -> ../../data/dataset/s1_processed/videos/bwis8n.mpg
# Change dir for ../../data/dataset/s1_processed/pbiizn.mpg -> ../../data/dataset/s1_processed/videos/pbiizn.mpg
# Change dir for ../../data/dataset/s1_processed/bbaz5s.mpg -> ../../data/dataset/s1_processed/videos/bbaz5s.mpg
# Change dir for ../../data/dataset/s1_processed/sbinzp.mpg -> ../../data/dataset/s1_processed/videos/sbinzp.mpg
# Change dir for ../../data/dataset/s1_processed/pbbc7a.mpg -> ../../data/dataset/s1_processed/videos/pbbc7a.mpg
# Change dir for ../../data/dataset/s1_processed/pwby1a.mpg -> ../../data/dataset/s1_processed/videos/pwby1a.mpg
# Change dir for ../../data/dataset/s1_processed/srwczp.mpg -> ../../data/dataset/s1_processed/videos/srwczp.mpg
# Change dir for ../../data/dataset/s1_processed/lgil7a.mpg -> ../../data/dataset/s1_processed/videos/lgil7a.mpg
# Change dir for ../../data/dataset/s1_processed/lbij6n.mpg -> ../../data/dataset/s1_processed/videos/lbij6n.mpg
# Change dir for ../../data/dataset/s1_processed/prwd6p.mpg -> ../../data/dataset/s1_processed/videos/prwd6p.mpg
# Change dir for ../../data/dataset/s1_processed/lgaz8p.mpg -> ../../data/dataset/s1_processed/videos/lgaz8p.mpg
# Change dir for ../../data/dataset/s1_processed/lgwtzn.mpg -> ../../data/dataset/s1_processed/videos/lgwtzn.mpg
# Change dir for ../../data/dataset/s1_processed/lwwz8n.mpg -> ../../data/dataset/s1_processed/videos/lwwz8n.mpg
# Change dir for ../../data/dataset/s1_processed/pgiq3s.mpg -> ../../data/dataset/s1_processed/videos/pgiq3s.mpg
# Change dir for ../../data/dataset/s1_processed/prax1a.mpg -> ../../data/dataset/s1_processed/videos/prax1a.mpg
# Change dir for ../../data/dataset/s1_processed/sbbuzn.mpg -> ../../data/dataset/s1_processed/videos/sbbuzn.mpg
# Change dir for ../../data/dataset/s1_processed/brif6p.mpg -> ../../data/dataset/s1_processed/videos/brif6p.mpg
# Change dir for ../../data/dataset/s1_processed/bwam8n.mpg -> ../../data/dataset/s1_processed/videos/bwam8n.mpg
# Change dir for ../../data/dataset/s1_processed/srbb6p.mpg -> ../../data/dataset/s1_processed/videos/srbb6p.mpg
# Change dir for ../../data/dataset/s1_processed/sgav7a.mpg -> ../../data/dataset/s1_processed/videos/sgav7a.mpg
# Change dir for ../../data/dataset/s1_processed/lwae8n.mpg -> ../../data/dataset/s1_processed/videos/lwae8n.mpg
# Change dir for ../../data/dataset/s1_processed/pgaq8p.mpg -> ../../data/dataset/s1_processed/videos/pgaq8p.mpg
# Change dir for ../../data/dataset/s1_processed/swwv8p.mpg -> ../../data/dataset/s1_processed/videos/swwv8p.mpg
# Change dir for ../../data/dataset/s1_processed/pwbx8n.mpg -> ../../data/dataset/s1_processed/videos/pwbx8n.mpg
# Change dir for ../../data/dataset/s1_processed/pwwq8n.mpg -> ../../data/dataset/s1_processed/videos/pwwq8n.mpg
# Change dir for ../../data/dataset/s1_processed/lgiz3s.mpg -> ../../data/dataset/s1_processed/videos/lgiz3s.mpg
# Change dir for ../../data/dataset/s1_processed/lrwf2p.mpg -> ../../data/dataset/s1_processed/videos/lrwf2p.mpg
# Change dir for ../../data/dataset/s1_processed/bgwo4p.mpg -> ../../data/dataset/s1_processed/videos/bgwo4p.mpg
# Change dir for ../../data/dataset/s1_processed/bgat9s.mpg -> ../../data/dataset/s1_processed/videos/bgat9s.mpg
# Change dir for ../../data/dataset/s1_processed/srau2n.mpg -> ../../data/dataset/s1_processed/videos/srau2n.mpg
# Change dir for ../../data/dataset/s1_processed/pwaj7s.mpg -> ../../data/dataset/s1_processed/videos/pwaj7s.mpg
# Change dir for ../../data/dataset/s1_processed/pwad4p.mpg -> ../../data/dataset/s1_processed/videos/pwad4p.mpg
# Change dir for ../../data/dataset/s1_processed/bgah3a.mpg -> ../../data/dataset/s1_processed/videos/bgah3a.mpg
# Change dir for ../../data/dataset/s1_processed/sgwx4p.mpg -> ../../data/dataset/s1_processed/videos/sgwx4p.mpg
# Change dir for ../../data/dataset/s1_processed/brif4n.mpg -> ../../data/dataset/s1_processed/videos/brif4n.mpg
# Change dir for ../../data/dataset/s1_processed/srbb4n.mpg -> ../../data/dataset/s1_processed/videos/srbb4n.mpg
# Change dir for ../../data/dataset/s1_processed/bbiz3a.mpg -> ../../data/dataset/s1_processed/videos/bbiz3a.mpg
# Change dir for ../../data/dataset/s1_processed/pbbp5a.mpg -> ../../data/dataset/s1_processed/videos/pbbp5a.mpg
# Change dir for ../../data/dataset/s1_processed/lgwg4p.mpg -> ../../data/dataset/s1_processed/videos/lgwg4p.mpg
# Change dir for ../../data/dataset/s1_processed/lwbl7s.mpg -> ../../data/dataset/s1_processed/videos/lwbl7s.mpg
# Change dir for ../../data/dataset/s1_processed/brwn2p.mpg -> ../../data/dataset/s1_processed/videos/brwn2p.mpg
# Change dir for ../../data/dataset/s1_processed/sbia1s.mpg -> ../../data/dataset/s1_processed/videos/sbia1s.mpg
# Change dir for ../../data/dataset/s1_processed/lbby4p.mpg -> ../../data/dataset/s1_processed/videos/lbby4p.mpg
# Change dir for ../../data/dataset/s1_processed/pbwx3a.mpg -> ../../data/dataset/s1_processed/videos/pbwx3a.mpg
# Change dir for ../../data/dataset/s1_processed/pgix7s.mpg -> ../../data/dataset/s1_processed/videos/pgix7s.mpg
# Change dir for ../../data/dataset/s1_processed/sgiv1s.mpg -> ../../data/dataset/s1_processed/videos/sgiv1s.mpg
# Change dir for ../../data/dataset/s1_processed/prbd2p.mpg -> ../../data/dataset/s1_processed/videos/prbd2p.mpg
# Change dir for ../../data/dataset/s1_processed/prwd4n.mpg -> ../../data/dataset/s1_processed/videos/prwd4n.mpg
# Change dir for ../../data/dataset/s1_processed/pgbe4p.mpg -> ../../data/dataset/s1_processed/videos/pgbe4p.mpg
# Change dir for ../../data/dataset/s1_processed/pwwy5a.mpg -> ../../data/dataset/s1_processed/videos/pwwy5a.mpg
# Change dir for ../../data/dataset/s1_processed/pbav2n.mpg -> ../../data/dataset/s1_processed/videos/pbav2n.mpg
# Change dir for ../../data/dataset/s1_processed/sgai7s.mpg -> ../../data/dataset/s1_processed/videos/sgai7s.mpg
# Change dir for ../../data/dataset/s1_processed/lbwr5a.mpg -> ../../data/dataset/s1_processed/videos/lbwr5a.mpg
# Change dir for ../../data/dataset/s1_processed/bbas1s.mpg -> ../../data/dataset/s1_processed/videos/bbas1s.mpg
# Change dir for ../../data/dataset/s1_processed/pgbk7s.mpg -> ../../data/dataset/s1_processed/videos/pgbk7s.mpg
# Change dir for ../../data/dataset/s1_processed/swio2p.mpg -> ../../data/dataset/s1_processed/videos/swio2p.mpg
# Change dir for ../../data/dataset/s1_processed/lbwk9s.mpg -> ../../data/dataset/s1_processed/videos/lbwk9s.mpg
# Change dir for ../../data/dataset/s1_processed/prwq5a.mpg -> ../../data/dataset/s1_processed/videos/prwq5a.mpg
# Change dir for ../../data/dataset/s1_processed/lbbe3a.mpg -> ../../data/dataset/s1_processed/videos/lbbe3a.mpg
# Change dir for ../../data/dataset/s1_processed/srin4n.mpg -> ../../data/dataset/s1_processed/videos/srin4n.mpg
# Change dir for ../../data/dataset/s1_processed/lwbf4p.mpg -> ../../data/dataset/s1_processed/videos/lwbf4p.mpg
# Change dir for ../../data/dataset/s1_processed/swwp4p.mpg -> ../../data/dataset/s1_processed/videos/swwp4p.mpg
# Change dir for ../../data/dataset/s1_processed/lrae5a.mpg -> ../../data/dataset/s1_processed/videos/lrae5a.mpg
# Change dir for ../../data/dataset/s1_processed/lgwm7s.mpg -> ../../data/dataset/s1_processed/videos/lgwm7s.mpg
# Change dir for ../../data/dataset/s1_processed/prbx5a.mpg -> ../../data/dataset/s1_processed/videos/prbx5a.mpg
# Change dir for ../../data/dataset/s1_processed/bram5a.mpg -> ../../data/dataset/s1_processed/videos/bram5a.mpg
# Change dir for ../../data/dataset/s1_processed/pwwe2p.mpg -> ../../data/dataset/s1_processed/videos/pwwe2p.mpg
# Change dir for ../../data/dataset/s1_processed/bwbn4p.mpg -> ../../data/dataset/s1_processed/videos/bwbn4p.mpg
# Change dir for ../../data/dataset/s1_processed/pbac3a.mpg -> ../../data/dataset/s1_processed/videos/pbac3a.mpg
# Change dir for ../../data/dataset/s1_processed/bbbm3a.mpg -> ../../data/dataset/s1_processed/videos/bbbm3a.mpg
# Change dir for ../../data/dataset/s1_processed/sgac4p.mpg -> ../../data/dataset/s1_processed/videos/sgac4p.mpg
# Change dir for ../../data/dataset/s1_processed/bgaa7s.mpg -> ../../data/dataset/s1_processed/videos/bgaa7s.mpg
# Change dir for ../../data/dataset/s1_processed/lrwz5a.mpg -> ../../data/dataset/s1_processed/videos/lrwz5a.mpg
# Change dir for ../../data/dataset/s1_processed/lrik2n.mpg -> ../../data/dataset/s1_processed/videos/lrik2n.mpg
# Change dir for ../../data/dataset/s1_processed/swbc2p.mpg -> ../../data/dataset/s1_processed/videos/swbc2p.mpg
# Change dir for ../../data/dataset/s1_processed/swwc4n.mpg -> ../../data/dataset/s1_processed/videos/swwc4n.mpg
# Change dir for ../../data/dataset/s1_processed/bwig2p.mpg -> ../../data/dataset/s1_processed/videos/bwig2p.mpg
# Change dir for ../../data/dataset/s1_processed/pbbi9s.mpg -> ../../data/dataset/s1_processed/videos/pbbi9s.mpg
# Change dir for ../../data/dataset/s1_processed/sgwd3a.mpg -> ../../data/dataset/s1_processed/videos/sgwd3a.mpg
# Change dir for ../../data/dataset/s1_processed/sbwb2n.mpg -> ../../data/dataset/s1_processed/videos/sbwb2n.mpg
# Change dir for ../../data/dataset/s1_processed/pwip7s.mpg -> ../../data/dataset/s1_processed/videos/pwip7s.mpg
# Change dir for ../../data/dataset/s1_processed/bris5a.mpg -> ../../data/dataset/s1_processed/videos/bris5a.mpg
# Change dir for ../../data/dataset/s1_processed/srab2p.mpg -> ../../data/dataset/s1_processed/videos/srab2p.mpg
# Change dir for ../../data/dataset/s1_processed/sgib9s.mpg -> ../../data/dataset/s1_processed/videos/sgib9s.mpg
# Change dir for ../../data/dataset/s1_processed/prbp8n.mpg -> ../../data/dataset/s1_processed/videos/prbp8n.mpg
# Change dir for ../../data/dataset/s1_processed/bgbh7a.mpg -> ../../data/dataset/s1_processed/videos/bgbh7a.mpg
# Change dir for ../../data/dataset/s1_processed/pbap1a.mpg -> ../../data/dataset/s1_processed/videos/pbap1a.mpg
# Change dir for ../../data/dataset/s1_processed/lwar8p.mpg -> ../../data/dataset/s1_processed/videos/lwar8p.mpg
# Change dir for ../../data/dataset/s1_processed/lwal3s.mpg -> ../../data/dataset/s1_processed/videos/lwal3s.mpg
# Change dir for ../../data/dataset/s1_processed/lrws1a.mpg -> ../../data/dataset/s1_processed/videos/lrws1a.mpg
# Change dir for ../../data/dataset/s1_processed/srbu6n.mpg -> ../../data/dataset/s1_processed/videos/srbu6n.mpg
# Change dir for ../../data/dataset/s1_processed/swwc6p.mpg -> ../../data/dataset/s1_processed/videos/swwc6p.mpg
# Change dir for ../../data/dataset/s1_processed/srbu9a.mpg -> ../../data/dataset/s1_processed/videos/srbu9a.mpg
# Change dir for ../../data/dataset/s1_processed/bbifzp.mpg -> ../../data/dataset/s1_processed/videos/bbifzp.mpg
# Change dir for ../../data/dataset/s1_processed/lrbz1a.mpg -> ../../data/dataset/s1_processed/videos/lrbz1a.mpg
# Change dir for ../../data/dataset/s1_processed/sbbbzp.mpg -> ../../data/dataset/s1_processed/videos/sbbbzp.mpg
# Change dir for ../../data/dataset/s1_processed/pbio7a.mpg -> ../../data/dataset/s1_processed/videos/pbio7a.mpg
# Change dir for ../../data/dataset/s1_processed/pgwy8n.mpg -> ../../data/dataset/s1_processed/videos/pgwy8n.mpg
# Change dir for ../../data/dataset/s1_processed/bbwm7a.mpg -> ../../data/dataset/s1_processed/videos/bbwm7a.mpg
# Change dir for ../../data/dataset/s1_processed/pgbrzn.mpg -> ../../data/dataset/s1_processed/videos/pgbrzn.mpg
# Change dir for ../../data/dataset/s1_processed/pbwdzp.mpg -> ../../data/dataset/s1_processed/videos/pbwdzp.mpg
# Change dir for ../../data/dataset/s1_processed/sbat9a.mpg -> ../../data/dataset/s1_processed/videos/sbat9a.mpg
# Change dir for ../../data/dataset/s1_processed/pbbv6n.mpg -> ../../data/dataset/s1_processed/videos/pbbv6n.mpg
# Change dir for ../../data/dataset/s1_processed/lwir3s.mpg -> ../../data/dataset/s1_processed/videos/lwir3s.mpg
# Change dir for ../../data/dataset/s1_processed/pbbv9a.mpg -> ../../data/dataset/s1_processed/videos/pbbv9a.mpg
# Change dir for ../../data/dataset/s1_processed/sgapzn.mpg -> ../../data/dataset/s1_processed/videos/sgapzn.mpg
# Change dir for ../../data/dataset/s1_processed/bbbs5s.mpg -> ../../data/dataset/s1_processed/videos/bbbs5s.mpg
# Change dir for ../../data/dataset/s1_processed/lrwr8n.mpg -> ../../data/dataset/s1_processed/videos/lrwr8n.mpg
# Change dir for ../../data/dataset/s1_processed/pgak3s.mpg -> ../../data/dataset/s1_processed/videos/pgak3s.mpg
# Change dir for ../../data/dataset/s1_processed/sbat6n.mpg -> ../../data/dataset/s1_processed/videos/sbat6n.mpg
# Change dir for ../../data/dataset/s1_processed/lgbs8p.mpg -> ../../data/dataset/s1_processed/videos/lgbs8p.mpg
# Change dir for ../../data/dataset/s1_processed/swih8p.mpg -> ../../data/dataset/s1_processed/videos/swih8p.mpg
# Change dir for ../../data/dataset/s1_processed/prii6n.mpg -> ../../data/dataset/s1_processed/videos/prii6n.mpg
# Change dir for ../../data/dataset/s1_processed/lgbm3s.mpg -> ../../data/dataset/s1_processed/videos/lgbm3s.mpg
# Change dir for ../../data/dataset/s1_processed/srin6p.mpg -> ../../data/dataset/s1_processed/videos/srin6p.mpg
# Change dir for ../../data/dataset/s1_processed/prii9a.mpg -> ../../data/dataset/s1_processed/videos/prii9a.mpg
# Change dir for ../../data/dataset/s1_processed/prbq1a.mpg -> ../../data/dataset/s1_processed/videos/prbq1a.mpg
# Change dir for ../../data/dataset/s1_processed/lbwe7a.mpg -> ../../data/dataset/s1_processed/videos/lbwe7a.mpg
# Change dir for ../../data/dataset/s1_processed/prii8p.mpg -> ../../data/dataset/s1_processed/videos/prii8p.mpg
# Change dir for ../../data/dataset/s1_processed/lwilzp.mpg -> ../../data/dataset/s1_processed/videos/lwilzp.mpg
# Change dir for ../../data/dataset/s1_processed/lgwazp.mpg -> ../../data/dataset/s1_processed/videos/lgwazp.mpg
# Change dir for ../../data/dataset/s1_processed/srin7a.mpg -> ../../data/dataset/s1_processed/videos/srin7a.mpg
# Change dir for ../../data/dataset/s1_processed/swih6n.mpg -> ../../data/dataset/s1_processed/videos/swih6n.mpg
# ...
# Change dir for ../../data/dataset/s34_processed/srwl5p.mpg -> ../../data/dataset/s34_processed/videos/srwl5p.mpg
# Change dir for ../../data/dataset/s34_processed/bgaq6s.mpg -> ../../data/dataset/s34_processed/videos/bgaq6s.mpg
# Change dir for ../../data/dataset/s34_processed/sgwt2a.mpg -> ../../data/dataset/s34_processed/videos/sgwt2a.mpg
# Change dir for ../../data/dataset/s34_processed/bric4a.mpg -> ../../data/dataset/s34_processed/videos/bric4a.mpg
# Change dir for ../../data/dataset/s34_processed/sgir8s.mpg -> ../../data/dataset/s34_processed/videos/sgir8s.mpg
# Change dir for ../../data/dataset/s34_processed/bbab9n.mpg -> ../../data/dataset/s34_processed/videos/bbab9n.mpg
# Change dir for ../../data/dataset/s34_processed/pwwh2s.mpg -> ../../data/dataset/s34_processed/videos/pwwh2s.mpg
# Change dir for ../../data/dataset/s34_processed/swafza.mpg -> ../../data/dataset/s34_processed/videos/swafza.mpg
# Change dir for ../../data/dataset/s34_processed/pbbl9n.mpg -> ../../data/dataset/s34_processed/videos/pbbl9n.mpg
# Change dir for ../../data/dataset/s34_processed/bgad7n.mpg -> ../../data/dataset/s34_processed/videos/bgad7n.mpg
# Change dir for ../../data/dataset/s34_processed/pwig1p.mpg -> ../../data/dataset/s34_processed/videos/pwig1p.mpg
# Change dir for ../../data/dataset/s34_processed/lgbp6a.mpg -> ../../data/dataset/s34_processed/videos/lgbp6a.mpg
# Change dir for ../../data/dataset/s34_processed/brbp9p.mpg -> ../../data/dataset/s34_processed/videos/brbp9p.mpg
# Change dir for ../../data/dataset/s34_processed/lwai1p.mpg -> ../../data/dataset/s34_processed/videos/lwai1p.mpg
# Change dir for ../../data/dataset/s34_processed/srbe8a.mpg -> ../../data/dataset/s34_processed/videos/srbe8a.mpg
# Change dir for ../../data/dataset/s34_processed/sray6a.mpg -> ../../data/dataset/s34_processed/videos/sray6a.mpg
# Change dir for ../../data/dataset/s34_processed/srbl1p.mpg -> ../../data/dataset/s34_processed/videos/srbl1p.mpg
# Change dir for ../../data/dataset/s34_processed/lwib2s.mpg -> ../../data/dataset/s34_processed/videos/lwib2s.mpg
# Change dir for ../../data/dataset/s34_processed/lran9p.mpg -> ../../data/dataset/s34_processed/videos/lran9p.mpg
# Change dir for ../../data/dataset/s34_processed/sbip9n.mpg -> ../../data/dataset/s34_processed/videos/sbip9n.mpg
# Change dir for ../../data/dataset/s34_processed/sbad8a.mpg -> ../../data/dataset/s34_processed/videos/sbad8a.mpg
# Change dir for ../../data/dataset/s34_processed/lbwn9n.mpg -> ../../data/dataset/s34_processed/videos/lbwn9n.mpg
# Change dir for ../../data/dataset/s34_processed/bbbc4s.mpg -> ../../data/dataset/s34_processed/videos/bbbc4s.mpg
# Change dir for ../../data/dataset/s34_processed/pbaz6a.mpg -> ../../data/dataset/s34_processed/videos/pbaz6a.mpg
# Change dir for ../../data/dataset/s34_processed/pbbf8a.mpg -> ../../data/dataset/s34_processed/videos/pbbf8a.mpg
# Change dir for ../../data/dataset/s34_processed/brii7p.mpg -> ../../data/dataset/s34_processed/videos/brii7p.mpg
# Change dir for ../../data/dataset/s34_processed/lria7p.mpg -> ../../data/dataset/s34_processed/videos/lria7p.mpg
# Change dir for ../../data/dataset/s34_processed/bwwe1p.mpg -> ../../data/dataset/s34_processed/videos/bwwe1p.mpg
# Change dir for ../../data/dataset/s34_processed/lgbxza.mpg -> ../../data/dataset/s34_processed/videos/lgbxza.mpg
# Change dir for ../../data/dataset/s34_processed/lwbo9p.mpg -> ../../data/dataset/s34_processed/videos/lwbo9p.mpg
# Change dir for ../../data/dataset/s34_processed/bgwy9p.mpg -> ../../data/dataset/s34_processed/videos/bgwy9p.mpg
# Change dir for ../../data/dataset/s34_processed/lbwu6a.mpg -> ../../data/dataset/s34_processed/videos/lbwu6a.mpg
# Change dir for ../../data/dataset/s34_processed/brbc9n.mpg -> ../../data/dataset/s34_processed/videos/brbc9n.mpg
# Change dir for ../../data/dataset/s34_processed/lgwqza.mpg -> ../../data/dataset/s34_processed/videos/lgwqza.mpg
# Change dir for ../../data/dataset/s34_processed/bbbv7p.mpg -> ../../data/dataset/s34_processed/videos/bbbv7p.mpg
# Change dir for ../../data/dataset/s34_processed/sgbgza.mpg -> ../../data/dataset/s34_processed/videos/sgbgza.mpg
# Change dir for ../../data/dataset/s34_processed/bwij2s.mpg -> ../../data/dataset/s34_processed/videos/bwij2s.mpg
# Change dir for ../../data/dataset/s34_processed/lrwi1n.mpg -> ../../data/dataset/s34_processed/videos/lrwi1n.mpg
# Change dir for ../../data/dataset/s34_processed/pbwm4s.mpg -> ../../data/dataset/s34_processed/videos/pbwm4s.mpg
# Change dir for ../../data/dataset/s34_processed/sbaq6a.mpg -> ../../data/dataset/s34_processed/videos/sbaq6a.mpg
# Change dir for ../../data/dataset/s34_processed/lgwj4s.mpg -> ../../data/dataset/s34_processed/videos/lgwj4s.mpg
# Change dir for ../../data/dataset/s34_processed/brbd1p.mpg -> ../../data/dataset/s34_processed/videos/brbd1p.mpg
# Change dir for ../../data/dataset/s34_processed/pbbs6a.mpg -> ../../data/dataset/s34_processed/videos/pbbs6a.mpg
# Change dir for ../../data/dataset/s34_processed/lrit9p.mpg -> ../../data/dataset/s34_processed/videos/lrit9p.mpg
# Change dir for ../../data/dataset/s34_processed/bbav1n.mpg -> ../../data/dataset/s34_processed/videos/bbav1n.mpg
# Change dir for ../../data/dataset/s34_processed/prwm9n.mpg -> ../../data/dataset/s34_processed/videos/prwm9n.mpg
# Change dir for ../../data/dataset/s34_processed/sbaj9n.mpg -> ../../data/dataset/s34_processed/videos/sbaj9n.mpg
# Change dir for ../../data/dataset/s34_processed/pgbn7n.mpg -> ../../data/dataset/s34_processed/videos/pgbn7n.mpg
# Change dir for ../../data/dataset/s34_processed/pgia2s.mpg -> ../../data/dataset/s34_processed/videos/pgia2s.mpg
# Change dir for ../../data/dataset/s34_processed/pwis9p.mpg -> ../../data/dataset/s34_processed/videos/pwis9p.mpg
# Change dir for ../../data/dataset/s34_processed/sgal7n.mpg -> ../../data/dataset/s34_processed/videos/sgal7n.mpg
# Change dir for ../../data/dataset/s34_processed/bwwq9p.mpg -> ../../data/dataset/s34_processed/videos/bwwq9p.mpg
# Change dir for ../../data/dataset/s34_processed/swwm1p.mpg -> ../../data/dataset/s34_processed/videos/swwm1p.mpg
# Change dir for ../../data/dataset/s34_processed/lbig4s.mpg -> ../../data/dataset/s34_processed/videos/lbig4s.mpg
# Change dir for ../../data/dataset/s34_processed/pgbh4s.mpg -> ../../data/dataset/s34_processed/videos/pgbh4s.mpg
# Change dir for ../../data/dataset/s34_processed/lwbpza.mpg -> ../../data/dataset/s34_processed/videos/lwbpza.mpg
# Change dir for ../../data/dataset/s34_processed/sbix4s.mpg -> ../../data/dataset/s34_processed/videos/sbix4s.mpg
# Change dir for ../../data/dataset/s34_processed/lbbh1n.mpg -> ../../data/dataset/s34_processed/videos/lbbh1n.mpg
# Change dir for ../../data/dataset/s34_processed/lbwh7p.mpg -> ../../data/dataset/s34_processed/videos/lbwh7p.mpg
# Change dir for ../../data/dataset/s34_processed/bwbx9p.mpg -> ../../data/dataset/s34_processed/videos/bwbx9p.mpg
# Change dir for ../../data/dataset/s34_processed/sbayza.mpg -> ../../data/dataset/s34_processed/videos/sbayza.mpg
# Change dir for ../../data/dataset/s34_processed/brio9n.mpg -> ../../data/dataset/s34_processed/videos/brio9n.mpg
# Change dir for ../../data/dataset/s34_processed/srbk9n.mpg -> ../../data/dataset/s34_processed/videos/srbk9n.mpg
# Change dir for ../../data/dataset/s34_processed/lrig9n.mpg -> ../../data/dataset/s34_processed/videos/lrig9n.mpg
# Change dir for ../../data/dataset/s34_processed/pwam9p.mpg -> ../../data/dataset/s34_processed/videos/pwam9p.mpg
# Change dir for ../../data/dataset/s34_processed/sgaf6a.mpg -> ../../data/dataset/s34_processed/videos/sgaf6a.mpg
# Change dir for ../../data/dataset/s34_processed/sbid1n.mpg -> ../../data/dataset/s34_processed/videos/sbid1n.mpg
# Change dir for ../../data/dataset/s34_processed/sgir7n.mpg -> ../../data/dataset/s34_processed/videos/sgir7n.mpg
# Change dir for ../../data/dataset/s34_processed/prwg8a.mpg -> ../../data/dataset/s34_processed/videos/prwg8a.mpg
# Change dir for ../../data/dataset/s34_processed/sbbk4s.mpg -> ../../data/dataset/s34_processed/videos/sbbk4s.mpg
# Change dir for ../../data/dataset/s34_processed/bbio4s.mpg -> ../../data/dataset/s34_processed/videos/bbio4s.mpg
# Change dir for ../../data/dataset/s34_processed/prwn1p.mpg -> ../../data/dataset/s34_processed/videos/prwn1p.mpg
# Change dir for ../../data/dataset/s34_processed/srix9n.mpg -> ../../data/dataset/s34_processed/videos/srix9n.mpg
# Change dir for ../../data/dataset/s34_processed/bgad8s.mpg -> ../../data/dataset/s34_processed/videos/bgad8s.mpg
# Change dir for ../../data/dataset/s34_processed/prif5p.mpg -> ../../data/dataset/s34_processed/videos/prif5p.mpg
# Change dir for ../../data/dataset/s34_processed/lwbi5p.mpg -> ../../data/dataset/s34_processed/videos/lwbi5p.mpg
# Change dir for ../../data/dataset/s34_processed/lgap2a.mpg -> ../../data/dataset/s34_processed/videos/lgap2a.mpg
# Change dir for ../../data/dataset/s34_processed/sbid3p.mpg -> ../../data/dataset/s34_processed/videos/sbid3p.mpg
# Change dir for ../../data/dataset/s34_processed/lbwh5n.mpg -> ../../data/dataset/s34_processed/videos/lbwh5n.mpg
# Change dir for ../../data/dataset/s34_processed/swie5p.mpg -> ../../data/dataset/s34_processed/videos/swie5p.mpg
# Change dir for ../../data/dataset/s34_processed/lbbh3p.mpg -> ../../data/dataset/s34_processed/videos/lbbh3p.mpg
# Change dir for ../../data/dataset/s34_processed/bwaqzs.mpg -> ../../data/dataset/s34_processed/videos/bwaqzs.mpg
# Change dir for ../../data/dataset/s34_processed/lrah5p.mpg -> ../../data/dataset/s34_processed/videos/lrah5p.mpg
# Change dir for ../../data/dataset/s34_processed/bbwj4a.mpg -> ../../data/dataset/s34_processed/videos/bbwj4a.mpg
# Change dir for ../../data/dataset/s34_processed/srik4a.mpg -> ../../data/dataset/s34_processed/videos/srik4a.mpg
# Change dir for ../../data/dataset/s34_processed/bbav3p.mpg -> ../../data/dataset/s34_processed/videos/bbav3p.mpg
# Change dir for ../../data/dataset/s34_processed/brwd5p.mpg -> ../../data/dataset/s34_processed/videos/brwd5p.mpg
# Change dir for ../../data/dataset/s34_processed/pgit3n.mpg -> ../../data/dataset/s34_processed/videos/pgit3n.mpg
# Change dir for ../../data/dataset/s34_processed/lbwb4a.mpg -> ../../data/dataset/s34_processed/videos/lbwb4a.mpg
# Change dir for ../../data/dataset/s34_processed/bgbrzs.mpg -> ../../data/dataset/s34_processed/videos/bgbrzs.mpg
# Change dir for ../../data/dataset/s34_processed/bgwy8s.mpg -> ../../data/dataset/s34_processed/videos/bgwy8s.mpg
# Change dir for ../../data/dataset/s34_processed/bwij3p.mpg -> ../../data/dataset/s34_processed/videos/bwij3p.mpg
# Change dir for ../../data/dataset/s34_processed/bbbv6s.mpg -> ../../data/dataset/s34_processed/videos/bbbv6s.mpg
# Change dir for ../../data/dataset/s34_processed/lria6s.mpg -> ../../data/dataset/s34_processed/videos/lria6s.mpg
# Change dir for ../../data/dataset/s34_processed/pgbu4a.mpg -> ../../data/dataset/s34_processed/videos/pgbu4a.mpg
# Change dir for ../../data/dataset/s34_processed/lwbo8s.mpg -> ../../data/dataset/s34_processed/videos/lwbo8s.mpg
# Change dir for ../../data/dataset/s34_processed/prbt2a.mpg -> ../../data/dataset/s34_processed/videos/prbt2a.mpg
# Change dir for ../../data/dataset/s34_processed/lwao3n.mpg -> ../../data/dataset/s34_processed/videos/lwao3n.mpg
# Change dir for ../../data/dataset/s34_processed/brii6s.mpg -> ../../data/dataset/s34_processed/videos/brii6s.mpg
# Change dir for ../../data/dataset/s34_processed/bbbc5p.mpg -> ../../data/dataset/s34_processed/videos/bbbc5p.mpg
# Change dir for ../../data/dataset/s34_processed/lwib3p.mpg -> ../../data/dataset/s34_processed/videos/lwib3p.mpg
# Change dir for ../../data/dataset/s34_processed/lran8s.mpg -> ../../data/dataset/s34_processed/videos/lran8s.mpg
# Change dir for ../../data/dataset/s34_processed/bgaq5n.mpg -> ../../data/dataset/s34_processed/videos/bgaq5n.mpg
# Change dir for ../../data/dataset/s34_processed/brbp8s.mpg -> ../../data/dataset/s34_processed/videos/brbp8s.mpg
# Change dir for ../../data/dataset/s34_processed/bwbq3n.mpg -> ../../data/dataset/s34_processed/videos/bwbq3n.mpg
# Change dir for ../../data/dataset/s34_processed/swaz2a.mpg -> ../../data/dataset/s34_processed/videos/swaz2a.mpg
# Change dir for ../../data/dataset/s34_processed/pwat4a.mpg -> ../../data/dataset/s34_processed/videos/pwat4a.mpg
# Change dir for ../../data/dataset/s34_processed/pwwh3p.mpg -> ../../data/dataset/s34_processed/videos/pwwh3p.mpg
# Change dir for ../../data/dataset/s34_processed/brap3n.mpg -> ../../data/dataset/s34_processed/videos/brap3n.mpg
# Change dir for ../../data/dataset/s34_processed/lrwv2a.mpg -> ../../data/dataset/s34_processed/videos/lrwv2a.mpg
# Change dir for ../../data/dataset/s34_processed/sgir9p.mpg -> ../../data/dataset/s34_processed/videos/sgir9p.mpg
# Change dir for ../../data/dataset/s34_processed/pwam7n.mpg -> ../../data/dataset/s34_processed/videos/pwam7n.mpg
# Change dir for ../../data/dataset/s34_processed/pwwh1n.mpg -> ../../data/dataset/s34_processed/videos/pwwh1n.mpg
# Change dir for ../../data/dataset/s34_processed/swwf8a.mpg -> ../../data/dataset/s34_processed/videos/swwf8a.mpg
# Change dir for ../../data/dataset/s34_processed/pbiz1p.mpg -> ../../data/dataset/s34_processed/videos/pbiz1p.mpg
# Change dir for ../../data/dataset/s34_processed/pgaa8a.mpg -> ../../data/dataset/s34_processed/videos/pgaa8a.mpg
# Change dir for ../../data/dataset/s34_processed/pgah1p.mpg -> ../../data/dataset/s34_processed/videos/pgah1p.mpg
# Change dir for ../../data/dataset/s34_processed/sbak1p.mpg -> ../../data/dataset/s34_processed/videos/sbak1p.mpg
# Change dir for ../../data/dataset/s34_processed/srbr6a.mpg -> ../../data/dataset/s34_processed/videos/srbr6a.mpg
# Change dir for ../../data/dataset/s34_processed/briv6a.mpg -> ../../data/dataset/s34_processed/videos/briv6a.mpg
# Change dir for ../../data/dataset/s34_processed/bwwq7n.mpg -> ../../data/dataset/s34_processed/videos/bwwq7n.mpg
# Change dir for ../../data/dataset/s34_processed/srwl4s.mpg -> ../../data/dataset/s34_processed/videos/srwl4s.mpg
# Change dir for ../../data/dataset/s34_processed/bwip8a.mpg -> ../../data/dataset/s34_processed/videos/bwip8a.mpg
# Change dir for ../../data/dataset/s34_processed/bwbx7n.mpg -> ../../data/dataset/s34_processed/videos/bwbx7n.mpg
# Change dir for ../../data/dataset/s34_processed/lgio8a.mpg -> ../../data/dataset/s34_processed/videos/lgio8a.mpg
# Change dir for ../../data/dataset/s34_processed/bgaq7p.mpg -> ../../data/dataset/s34_processed/videos/bgaq7p.mpg
# Change dir for ../../data/dataset/s34_processed/swwl9n.mpg -> ../../data/dataset/s34_processed/videos/swwl9n.mpg
# Change dir for ../../data/dataset/s34_processed/pbiy9n.mpg -> ../../data/dataset/s34_processed/videos/pbiy9n.mpg
# Change dir for ../../data/dataset/s34_processed/pgbn9p.mpg -> ../../data/dataset/s34_processed/videos/pgbn9p.mpg
# Change dir for ../../data/dataset/s34_processed/lwib1n.mpg -> ../../data/dataset/s34_processed/videos/lwib1n.mpg
# Change dir for ../../data/dataset/s34_processed/lrit7n.mpg -> ../../data/dataset/s34_processed/videos/lrit7n.mpg
# Change dir for ../../data/dataset/s34_processed/sgal9p.mpg -> ../../data/dataset/s34_processed/videos/sgal9p.mpg
# Change dir for ../../data/dataset/s34_processed/pwag6a.mpg -> ../../data/dataset/s34_processed/videos/pwag6a.mpg
# Change dir for ../../data/dataset/s34_processed/pwis7n.mpg -> ../../data/dataset/s34_processed/videos/pwis7n.mpg
# Change dir for ../../data/dataset/s34_processed/prwt6a.mpg -> ../../data/dataset/s34_processed/videos/prwt6a.mpg
# Change dir for ../../data/dataset/s34_processed/bbwx1p.mpg -> ../../data/dataset/s34_processed/videos/bbwx1p.mpg
# Change dir for ../../data/dataset/s34_processed/srwsza.mpg -> ../../data/dataset/s34_processed/videos/srwsza.mpg
# Change dir for ../../data/dataset/s34_processed/bwij1n.mpg -> ../../data/dataset/s34_processed/videos/bwij1n.mpg
# Change dir for ../../data/dataset/s34_processed/lrwi2s.mpg -> ../../data/dataset/s34_processed/videos/lrwi2s.mpg
# Change dir for ../../data/dataset/s34_processed/srbzza.mpg -> ../../data/dataset/s34_processed/videos/srbzza.mpg
# Change dir for ../../data/dataset/s34_processed/sriy1p.mpg -> ../../data/dataset/s34_processed/videos/sriy1p.mpg
# Completed!

# %% [markdown]
# ## Extract mono 16 kHz audio from videos
#
# This cell scans each speaker folder (excluding `s21`), finds all `*.mpg` in `videos/`,
# and writes the audio tracks to `audio/` as mono 16 kHz WAV (`pcm_s16le`).
# - Idempotent: existing WAVs are skipped.
# - Progress bars show per-speaker and per-file status.
# - Requires `ffmpeg` (MoviePy uses it under the hood).

# %%
for i in tqdm([x for x in range(1, 35) if x != 21], desc=f"Extraction"):
    subject_dir = ROOT / f"s{i}_processed"
    videos_dir = subject_dir / "videos"
    audio_dir = subject_dir / "audio"
    audio_dir.mkdir(exist_ok=True)

    mpg_files = sorted(videos_dir.glob("*.mpg"))
    if not mpg_files:
        tqdm.write(f"No .mpg file found in {videos_dir}")
        continue

    file_bar = tqdm(mpg_files, desc=f"s{i} audio extraction", leave=False)
    for mpg_path in file_bar:
        wav_path = audio_dir / (mpg_path.stem + ".wav")
        if wav_path.exists():
            continue

        try:
            with VideoFileClip(str(mpg_path)) as clip:
                clip.audio.write_audiofile(
                    str(wav_path),
                    fps=16000,
                    nbytes=2,
                    codec='pcm_s16le',
                    logger=None
                )
            file_bar.set_postfix_str(f"Extracting: {mpg_path.name}")
        except Exception as e:
            file_bar.set_postfix_str(f"Error: {mpg_path.name}")
            tqdm.write(f"Error with {mpg_path}: {e}")
    file_bar.close()

print("Extraction completed!")
# Out:
# Extraction:  18%|█▊        | 6/33 [03:09<17:40, 39.28s/it]Exception ignored in: <function FFMPEG_AudioReader.__del__ at 0x1075b0720>
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/moviepy/audio/io/readers.py", line 304, in __del__
#     self.close()
#   File "/opt/anaconda3/lib/python3.12/site-packages/moviepy/audio/io/readers.py", line 294, in close
#     if self.proc:
#        ^^^^^^^^^
# AttributeError: 'FFMPEG_AudioReader' object has no attribute 'proc'
# Extraction: 100%|██████████| 33/33 [36:28<00:00, 66.33s/it]
# Extraction completed!

# %% [markdown]
# ## Create noisy counterparts at target SNR
#
# This cell generates a noisy version of every clean WAV per speaker (excluding `s21`) and
# writes it to `audio_noisy/` with the same filename. Gaussian noise is added to reach a
# target Signal-to-Noise Ratio (SNR) in dB, sampled uniformly from a range (default: 5–100 dB).
#
# - **Idempotent:** existing files are skipped.
# - **Mono handling:** if an input WAV is stereo, only the first channel is used.
# - **SNR sampling:** adjust `snr_range` (e.g., 5–20 dB) for more realistic conditions.
# - **Reproducibility:** set `random.seed(...)` before the loop if deterministic noise is desired.

# %%
def add_noise(audio, snr_db) -> np.ndarray:
    """
    Adds Gaussian noise to an audio signal at the specified SNR (in dB).

    Args:
        audio (np.ndarray): The input audio signal.
        snr_db (float): Desired signal-to-noise ratio in decibels.

    Returns:
        np.ndarray: The noisy audio signal.
    """
    signal_power = np.mean(audio ** 2)
    snr_linear   = 10 ** (snr_db / 10)
    noise_power  = signal_power / snr_linear
    noise        = np.random.normal(0, np.sqrt(noise_power), audio.shape)
    return audio + noise

snr_range = (5,100)

for i in tqdm([x for x in range(1,35) if x != 21], desc="Noising"):
    subject_dir = ROOT / f"s{i}_processed"
    audio_dir   = subject_dir / "audio"
    noisy_dir   = subject_dir / "audio_noisy"
    noisy_dir.mkdir(exist_ok=True)

    wav_files = sorted(audio_dir.glob("*.wav"))
    if not wav_files:
        tqdm.write(f"No .wav file found in {audio_dir}")
        continue

    for wav_path in tqdm(wav_files, desc=f"s{i} add noise", leave=False):
        out_path = noisy_dir / wav_path.name
        if out_path.exists(): continue

        audio, sr = sf.read(str(wav_path))
        if len(audio.shape) > 1:
            audio = audio[:, 0]

        snr_db      = random.uniform(*snr_range)
        noisy_audio = add_noise(audio, snr_db=snr_db)
        sf.write(str(out_path), noisy_audio, sr)

print("Add noise!")
# Out:
# Noising: 100%|██████████| 33/33 [00:00<00:00, 75.24it/s]
# Add noise!

# %% [markdown]
# ## Create aligned train/val/test splits (by stem)
#
# This step splits each speaker’s data into **train/val/test = 80/10/10** using a seeded
# shuffle (`seed=42`). File stems present **in all three modalities** (`audio/*.wav`,
# `audio_noisy/*.wav`, `videos/*.mpg`) are intersected to avoid mismatches; only those
# common items are split.
#
# - **Aligned across modalities:** the same stems go to the same split for audio, noisy audio, and video.
# - **Deterministic:** fixed random seed for reproducible partitions.
# - **Idempotent:** creates `train/val/test` subfolders and moves files there; skipping missing files.
# - **Adjustable:** change `split_ratios` to modify the partition (e.g., `[0.9, 0.05, 0.05]`).
#
# After this, each `sX_processed/{audio,audio_noisy,videos}/` directory contains
# `train/`, `val/`, and `test/` subfolders with perfectly synchronized items.

# %%
split_ratios = [0.8, 0.1, 0.1]
random.seed(42)

for i in tqdm([x for x in range(1, 35) if x != 21], desc="Separation"):
    subject     = ROOT / f"s{i}_processed"
    base_names  = {p.stem for p in (subject/"audio").glob("*.wav")}
    base_names &= {p.stem for p in (subject/"videos").glob("*.mpg")} 
    base_names &= {p.stem for p in (subject/"audio_noisy").glob("*.wav")}

    base_list   = sorted(list(base_names))
    random.shuffle(base_list)
    n           = len(base_list)
    n_train     = int(split_ratios[0] * n)
    n_val       = int(split_ratios[1] * n)

    splits = {
        "train": base_list[:n_train],
        "val":   base_list[n_train:n_train+n_val],
        "test":  base_list[n_train+n_val:]
    }

    for modality in ["audio", "audio_noisy", "videos"]:
        mod_dir = subject / modality
        if not mod_dir.exists():
            continue
        for split, names in splits.items():
            target = mod_dir / split
            target.mkdir(exist_ok=True)
            for nm in names:
                ext = ".wav" if "audio" in modality else ".mpg"
                src = mod_dir / (nm + ext)
                if src.exists():
                    shutil.move(str(src), target / src.name)

print("Split completed!")
# Out:
# Separation: 100%|██████████| 33/33 [00:07<00:00,  4.31it/s]
# Split completed!

# %% [markdown]
# ## Offline Mel-spectrogram precomputation
#
# This step converts every `.wav` in each split (`audio/` and `audio_noisy/`) to a
# log-Mel spectrogram and saves it as a NumPy array (`.npy`) with the same stem.
#
# - **I/O:** reads `…/audio{,_noisy}/{train,val,test}/*.wav`, writes to
#   `…/audio_mel/` and `…/audio_noisy_mel/` mirroring the split structure.
# - **Features:** `librosa.feature.melspectrogram` at 16 kHz with `n_mels=80`
#   (configurable), then `power_to_db` (log scale). Output shape is
#   `[n_mels, T]`.
# - **Idempotent:** skips files that already exist.
# - **Consistency tip:** keep Mel params (`sr`, `n_mels`, `n_fft`, hop, window,
#   `power`) aligned with what the model expects. If the training pipeline uses
#   linear magnitude (`power=1.0`), set that here as well.
#
# After this stage, dataloaders can directly `np.load()` Mel tensors from disk for
# faster, repeatable training.

# %%
def extract_and_save_mel(audio_path, out_path, sr=16000, n_mels=80) -> None:
    """
    Extracts the mel-spectrogram from an audio file and saves it as a NumPy array.

    Args:
        audio_path (str or Path): Path to the input audio file.
        out_path (str or Path): Path where the mel-spectrogram will be saved (.npy).
        sr (int, optional): Target sampling rate for audio loading. Default is 16000.
        n_mels (int, optional): Number of mel bands to generate. Default is 80.

    Returns:
        None
    """
    y, _    = librosa.load(audio_path, sr=sr)
    mel     = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)
    mel_db  = librosa.power_to_db(mel, ref=np.max)
    np.save(out_path, mel_db)

for i in tqdm([x for x in range(1,35) if x != 21], desc="Spectr"):
    subject_dir = ROOT / f"s{i}_processed"

    for typ in ["audio", "audio_noisy"]:
        for split in ["train", "val", "test"]:
            in_folder = subject_dir / typ / split
            if not in_folder.exists(): continue

            out_folder = subject_dir / f"{typ}_mel" / split
            out_folder.mkdir(parents=True, exist_ok=True)
            wav_files = list(in_folder.glob("*.wav"))

            for wav in tqdm(wav_files, desc=f"s{i}-{typ}/{split}", leave=False):
                out_path = out_folder / (wav.stem + ".npy")
                if out_path.exists(): continue
                extract_and_save_mel(str(wav), str(out_path))

print("MelSpect preprocessing completed!")
# Out:
# Spectr: 100%|██████████| 33/33 [04:50<00:00,  8.79s/it]
# MelSpect preprocessing completed!
